# %%
import pandas as pd

path = "/Users/jayant/Desktop/LifeCost/Scrapping_Manual/cpi/Centre group index   Official website of Labour Bureau, Ministry of Labour and Employment,Government of India.xlsx"

df = pd.read_excel(path)

# Fix column names
df.columns = ["SNo", "BaseYear", "State", "Centre", "Group", "Year", "Month", "Index"]

# Drop header row that got imported as data
df = df[df["BaseYear"] != "Base Year"]

# Convert types
df["Year"] = df["Year"].astype(int)
df["Index"] = pd.to_numeric(df["Index"], errors="coerce")

df.head()
# Out:
#   SNo BaseYear           State  Centre             Group  Year Month  Index
# 1   1     2016  ANDHRA PRADESH  Guntur  Food & Beverages  2021   Jan  114.9
# 2   2     2016  ANDHRA PRADESH  Guntur  Food & Beverages  2022   Jan  125.7
# 3   3     2016  ANDHRA PRADESH  Guntur  Food & Beverages  2023   Jan  141.6
# 4   4     2016  ANDHRA PRADESH  Guntur  Food & Beverages  2024   Jan  148.0
# 5   5     2016  ANDHRA PRADESH  Guntur  Food & Beverages  2025   Jan  155.8

# %%
bhopal = df[
    (df["Centre"].str.upper() == "BHOPAL") &
    (df["Group"] == "All Items")
].sort_values(["Year", "Month"])

bhopal.head()
# Out:
# Empty DataFrame
# Columns: [SNo, BaseYear, State, Centre, Group, Year, Month, Index]
# Index: []

# %%
bhopal["Inflation_YoY_%"] = (
    bhopal["Index"].pct_change(12) * 100
).round(2)

bhopal.tail()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 bhopal["Inflation_YoY_%"] = (
# ----> 2     bhopal["Index"].pct_change(12) * 100
#       3 ).round(2)
#       5 bhopal.tail()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:11704, in NDFrame.pct_change(self, periods, fill_method, limit, freq, **kwargs)
#   11702 for _, col in cols:
#   11703     mask = col.isna().values
# > 11704     mask = mask[np.argmax(~mask) :]
#   11705     if mask.any():
#   11706         warnings.warn(
#   11707             "The default fill_method='pad' in "
#   11708             f"{type(self).__name__}.pct_change is deprecated and will "
#    (...)
#   11713             stacklevel=find_stack_level(),
#   11714         )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:1229, in argmax(a, axis, out, keepdims)
#    1142 """
#    1143 Returns the indices of the maximum values along an axis.
#    1144
#    (...)
#    1226 (2, 1, 4)
#    1227 """
#    1228 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1229 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: attempt to get argmax of an empty sequence

# %%
bhopal.to_excel("/mnt/data/bhopal_cpi_clean.xlsx", index=False)
bhopal.to_csv("/mnt/data/bhopal_cpi_clean.csv", index=False)
